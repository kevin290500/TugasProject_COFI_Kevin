# %%
pip install plotnine
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from plotnine.data import msleep
from plotnine import ggplot, aes, geom_point
msleep
# Out:
#                           name       genus   vore         order  conservation  \
# 0                      Cheetah    Acinonyx  carni     Carnivora            lc
# 1                   Owl monkey       Aotus   omni      Primates           NaN
# 2              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 3   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 4                          Cow         Bos  herbi  Artiodactyla  domesticated
# ..                         ...         ...    ...           ...           ...
# 78                  Tree shrew      Tupaia   omni    Scandentia           NaN
# 79        Bottle-nosed dolphin    Tursiops  carni       Cetacea           NaN
# 80                       Genet     Genetta  carni     Carnivora           NaN
# 81                  Arctic fox      Vulpes  carni     Carnivora           NaN
# 82                     Red fox      Vulpes  carni     Carnivora           NaN
#
# ...

# %%
msleep.dtypes
# Out:
# name              object
# genus             object
# vore            category
# order             object
# conservation    category
# sleep_total      float64
# sleep_rem        float64
# sleep_cycle      float64
# awake            float64
# brainwt          float64
# bodywt           float64
# dtype: object

# %%
msleep.isnull().sum()
# Out:
# name             0
# genus            0
# vore             7
# order            0
# conservation    29
# sleep_total      0
# sleep_rem       21
# sleep_cycle     50
# awake            0
# brainwt         25
# bodywt           0
# dtype: int64

# %%
msleep.duplicated().sum()
# Out:
# 0

# %%
modus = msleep['vore'].mode()[0]
modus2 = msleep['conservation'].mode()[0]
modus3 = msleep['sleep_rem'].mode()[0]
modus4 = msleep['sleep_cycle'].mode()[0]
modus5 = msleep['brainwt'].mode()[0]

msleep['vore'] = msleep['vore'].fillna(modus)
msleep['conservation'] = msleep['conservation'].fillna(modus2)
msleep['sleep_rem'] = msleep['sleep_rem'].fillna(modus3)
msleep['sleep_cycle'] = msleep['sleep_cycle'].fillna(modus4)
msleep['brainwt'] = msleep['brainwt'].fillna(modus5)

# %%
msleep.isnull().sum()
# Out:
# name            0
# genus           0
# vore            0
# order           0
# conservation    0
# sleep_total     0
# sleep_rem       0
# sleep_cycle     0
# awake           0
# brainwt         0
# bodywt          0
# dtype: int64

# %%
msleep
# Out:
#                           name       genus   vore         order  conservation  \
# 0                      Cheetah    Acinonyx  carni     Carnivora            lc
# 1                   Owl monkey       Aotus   omni      Primates            lc
# 2              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 3   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 4                          Cow         Bos  herbi  Artiodactyla  domesticated
# ..                         ...         ...    ...           ...           ...
# 78                  Tree shrew      Tupaia   omni    Scandentia            lc
# 79        Bottle-nosed dolphin    Tursiops  carni       Cetacea            lc
# 80                       Genet     Genetta  carni     Carnivora            lc
# 81                  Arctic fox      Vulpes  carni     Carnivora            lc
# 82                     Red fox      Vulpes  carni     Carnivora            lc
#
# ...

# %%
# name :
# nama umum

# genus :

# vore:
# karnivora, omnivora atau herbivora?

# order :

# conservation:
# Status konservasi hewan

# sleep_total:
# jumlah total tidur, dalam jam

# sleep_rem :
# REM tidur, dalam hitungan jam

# sleep_cycle :
# panjang siklus tidur, dalam jam

# awake :
# jumlah waktu yang dihabiskan untuk bangun, dalam beberapa jam

# brainwt :
# berat otak dalam kilogram

# bodywt :
# berat badan dalam kilogram

msleep.corr()
# Out:
#              sleep_total  sleep_rem  sleep_cycle     awake   brainwt    bodywt
# sleep_total     1.000000   0.640296    -0.166656 -0.999999 -0.301042 -0.312011
# sleep_rem       0.640296   1.000000    -0.060518 -0.640289 -0.074402 -0.104024
# sleep_cycle    -0.166656  -0.060518     1.000000  0.166485  0.109267 -0.018150
# awake          -0.999999  -0.640289     0.166485  1.000000  0.300860  0.311980
# brainwt        -0.301042  -0.074402     0.109267  0.300860  1.000000  0.917798
# bodywt         -0.312011  -0.104024    -0.018150  0.311980  0.917798  1.000000

# %%
desc = msleep.describe()
# display
desc
# Out:
#        sleep_total  sleep_rem  sleep_cycle      awake    brainwt       bodywt
# count    83.000000  83.000000    83.000000  83.000000  83.000000    83.000000
# mean     10.433735   1.749398     0.282129  13.567470   0.192465   166.136349
# std       4.450357   1.130441     0.253736   4.452085   0.810255   786.839732
# min       1.900000   0.100000     0.116667   4.100000   0.000140     0.005000
# 25%       7.850000   1.150000     0.183333  10.250000   0.001000     0.174000
# 50%      10.100000   1.400000     0.183333  13.900000   0.003500     1.670000
# 75%      13.750000   2.200000     0.208333  16.150000   0.047450    41.750000
# max      19.900000   6.600000     1.500000  22.100000   5.712000  6654.000000

# %%
msleep
# Out:
#                           name       genus   vore         order  conservation  \
# 0                      Cheetah    Acinonyx  carni     Carnivora            lc
# 1                   Owl monkey       Aotus   omni      Primates            lc
# 2              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 3   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 4                          Cow         Bos  herbi  Artiodactyla  domesticated
# ..                         ...         ...    ...           ...           ...
# 78                  Tree shrew      Tupaia   omni    Scandentia            lc
# 79        Bottle-nosed dolphin    Tursiops  carni       Cetacea            lc
# 80                       Genet     Genetta  carni     Carnivora            lc
# 81                  Arctic fox      Vulpes  carni     Carnivora            lc
# 82                     Red fox      Vulpes  carni     Carnivora            lc
#
# ...

# %%
sns.set(style="whitegrid") 
plt.title('Jumlah waktu Bangun')
sns.scatterplot( msleep['sleep_total'], msleep['awake'],ci=None)
# Out:
# <AxesSubplot:title={'center':'Jumlah waktu Bangun'}, xlabel='sleep_total', ylabel='awake'>

# %% [markdown]
# **Pengaruh Waktu Tidur Terhadap Waktu Bangun**
# >Semakin banyak waktu tidur semakin cepat waktu bangun

# %%
sns.scatterplot( msleep['sleep_total'], msleep['sleep_rem'],ci=None)
# Out:
# <AxesSubplot:xlabel='sleep_total', ylabel='sleep_rem'>

# %% [markdown]
# **Pengaruh Waktu Tidur Terhadap Waktu Mimpi**
# >semakin banyak waktu tidur semakin banyak waktu bermimpi

# %%
sns.set(style="whitegrid") 
plt.title('Pengaruh Berat Badan dengan Berat Otak')
sns.lineplot( msleep['bodywt'], msleep['brainwt'],ci=None)
# Out:
# <AxesSubplot:title={'center':'Pengaruh Berat Badan dengan Berat Otak'}, xlabel='bodywt', ylabel='brainwt'>

# %% [markdown]
# **Pengaruh Berat Badan Terhadap Berat Otak**
# >Semakin besar berat badan maka semakin besar ukuran otak

# %%
sns.set(style="whitegrid") 
plt.title('Pengaruh Berat Otak dengan Lamanya Waktu Tidur')
sns.lineplot( msleep['sleep_total'], msleep['brainwt'],ci=None)
# Out:
# <AxesSubplot:title={'center':'Pengaruh Berat Otak dengan Lamanya Waktu Tidur'}, xlabel='sleep_total', ylabel='brainwt'>

# %% [markdown]
# **Pengaruh jumlah waktu tidur terhadap ukuran otak**
# >Semakin sedikit waktu tidur maka semakin besar ukuran otak
